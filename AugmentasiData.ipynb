# %% [markdown]
# <a href="https://colab.research.google.com/github/hiauls/Machinelearningpraktikum/blob/main/AugmentasiData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # KLASIFIKASI SEPATU ADIDAS DAN NIKE MENGGUNAKAN CONVOLUTIONAL NEURAL NETWORK (CNN)

# %% [markdown]
# ***Title :***
#   _KLASIFIKASI SEPATU ADIDAS DAN NIKE MENGGUNAKAN CONVOLUTIONAL NEURAL NETWORK (CNN)_
#
# ***Member Name :***
#   1. Iqmah Nurrizky A
#   2. Aulia Lintang Ayu K.
#
# ***Dataset :***
#   Rose Flowers Dataset
#
# ***Dataset Link :***
#   [Rose Flowers Dataset](https://www.kaggle.com/datasets/ifeanyinneji/nike-adidas-shoes-for-image-classification-dataset)
#
# ***Jurnal Referensi :***
#   [Jurnal Referensi](https://ibn.e-journal.id/index.php/ESENSI/article/view/67/55)

# %% [markdown]
# ## **LOAD DATASET & PRE - PROCESSING**

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd "/content/gdrive/MyDrive/MachineLearning"
# Out:
# /content/gdrive/MyDrive/MachineLearning

# %%
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.1.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2022.9.24)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.64.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/MyDrive/MachineLearning"

# %%
# !kaggle datasets download -d ifeanyinneji/nike-adidas-shoes-for-image-classification-dataset
# Out:
# Downloading nike-adidas-shoes-for-image-classification-dataset.zip to /content/gdrive/MyDrive/MachineLearning
#  55% 14.0M/25.7M [00:00<00:00, 142MB/s]
# 100% 25.7M/25.7M [00:00<00:00, 168MB/s]

# %%
# !unzip "/content/gdrive/MyDrive/MachineLearning/nike-adidas-shoes-for-image-classification-dataset.zip"
# Out:
# Archive:  /content/gdrive/MyDrive/MachineLearning/Images/nike-adidas-shoes-for-image-classification-dataset.zip
#   inflating: labelnames.csv
#   inflating: test/adidas/Adidas (18).jpg
#   inflating: test/adidas/Adidas (19).jpg
#   inflating: test/adidas/Adidas (20).jpg
#   inflating: test/adidas/Adidas (21).JPG
#   inflating: test/adidas/Adidas (22).jpg
#   inflating: test/adidas/Adidas (23).jpg
#   inflating: test/adidas/Adidas (24).jpg
#   inflating: test/adidas/Adidas (25).jpg
#   inflating: test/adidas/Adidas (26).jpg
#   inflating: test/adidas/Adidas (27).jpg
#   inflating: test/adidas/aadidas_ (10).jpg
#   inflating: test/adidas/aadidas_ (11).jpg
#   inflating: test/adidas/aadidas_ (12).jpg
#   inflating: test/adidas/aadidas_ (13).jpg
#   inflating: test/adidas/aadidas_ (14).jpg
#   inflating: test/adidas/aadidas_ (15).jpg
#   inflating: test/adidas/aadidas_ (16).jpg
#   inflating: test/adidas/aadidas_ (17).jpg
#   inflating: test/adidas/aadidas_ (18).jpg
#   inflating: test/adidas/aadidas_ (19).jpg
#   inflating: train/nike/Image_95.jpg
#   inflating: train/nike/Image_96.jpg
#   inflating: train/nike/Image_97.jpg
#   inflating: train/nike/Image_98.jpg
#   inflating: train/nike/Image_99.JPG
#   inflating: validation/adidas/adidas_ (149).jpg
#   inflating: validation/adidas/adidas_ (150).jpg
#   inflating: validation/adidas/adidas_ (151).jpg
#   inflating: validation/adidas/adidas_ (152).jpg
#   inflating: validation/adidas/adidas_ (153).jpg
#   inflating: validation/adidas/adidas_ (154).jpg
#   inflating: validation/adidas/adidas_ (155).jpg
#   inflating: validation/adidas/adidass_(11).jpg
#   inflating: validation/adidas/adidass_(12).jpg
#   inflating: validation/adidas/adidass_(13).jpg
#   inflating: validation/adidas/adidass_(14).jpg
#   inflating: validation/adidas/adidass_(15).jpg
#   inflating: validation/adidas/adidass_(16).jpg
#   inflating: validation/adidas/adidass_(17).jpg
#   inflating: validation/adidas/adidass_(18).jpg
#   inflating: validation/adidas/adidass_(19).jpg
#   inflating: validation/adidas/adidass_(20).jpg
#   inflating: validation/adidas/adidass_(21).jpg
#   inflating: validation/adidas/adidass_(22).jpg
#   inflating: validation/adidas/adidass_(23).jpg
#   inflating: validation/adidas/adidass_(24).jpg
#   inflating: validation/adidas/adidass_(25).jpg
#   inflating: validation/adidas/adidass_(26).jpg
#   inflating: validation/adidas/adidass_(27).jpg
#   inflating: validation/adidas/adidass_(28).jpg
#   inflating: validation/adidas/adidass_(29).jpg
#   inflating: validation/adidas/adidass_(30).jpg
#   inflating: validation/nike/Image_261.jpg
#   inflating: validation/nike/Image_262.jpg
#   inflating: validation/nike/Image_263.jpg
#   inflating: validation/nike/Image_264.jpg
#   inflating: validation/nike/Image_265.jpg
#   inflating: validation/nike/Image_266.jpg
#   inflating: validation/nike/Image_267.jpg
#   inflating: validation/nike/Image_268.jpg
#   inflating: validation/nike/Image_269.jpg
#   inflating: validation/nike/Image_270.jpg
#   inflating: validation/nike/Image_271.jpg
#   inflating: validation/nike/Image_272.jpg
#   inflating: validation/nike/Image_273.jpg
#   inflating: validation/nike/Image_274.jpg
#   inflating: validation/nike/Image_275.jpg
#   inflating: validation/nike/Image_276.JPG
#   inflating: validation/nike/Image_277.jpg
#   inflating: validation/nike/Image_278.jpg
#   inflating: validation/nike/Image_279.jpg
#   inflating: validation/nike/Image_280.jpg
#   inflating: validation/nike/Image_281.jpg
#   inflating: validation/nike/Image_282.jpg
#   inflating: validation/nike/Image_289.jpg
#   inflating: validation/nike/Image_290.jpg
#   inflating: validation/nike/Image_291.jpg
#   inflating: validation/nike/Image_292.jpg
#   inflating: validation/nike/Image_299.jpg
#   inflating: validation/nike/Image_300.jpg

# %%
# !pip install split-folders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
from keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import BatchNormalization
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report
import os
import zipfile
import shutil
import splitfolders
import cv2
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, Conv2D, MaxPool2D, Flatten, SpatialDropout2D
from sklearn.preprocessing import LabelEncoder

# %%
import os
base_dataset = "/content/gdrive/MyDrive/MachineLearning/test"
class_dir = ['adidas', 'nike']
for class_item in class_dir:
  cur_dir = base_dataset+"/"+class_item
  dataset = os.listdir(cur_dir)
  for item in dataset:
    if not item.endswith(".jpg"):
      os.remove(os.path.join(cur_dir, item))

# %%
# !mkdir "/content/gdrive/MyDrive/MachineLearning/shoes/"
# !mkdir "/content/gdrive/MyDrive/MachineLearning/shoes/adidas"
# !mkdir "/content/gdrive/MyDrive/MachineLearning/shoes/nike"
# !mkdir "/content/gdrive/MyDrive/MachineLearning/splitt"

# %%
adidas_images = "/content/gdrive/MyDrive/MachineLearning/shoes/adidas"
nike_images = "/content/gdrive/MyDrive/MachineLearning/shoes/nike"

test_adidas_dir = "/content/gdrive/MyDrive/MachineLearning/test/adidas"
train_adidas_dir = "/content/gdrive/MyDrive/MachineLearning/train/adidas"
val_adidas_dir = "/content/gdrive/MyDrive/MachineLearning/validation/adidas"

test_nike_dir = "/content/gdrive/MyDrive/MachineLearning/test/nike"
train_nike_dir = "/content/gdrive/MyDrive/MachineLearning/train/nike"
val_nike_dir = "/content/gdrive/MyDrive/MachineLearning/validation/nike"

# %% [markdown]
# **ADIDAS**

# %%
temp_test_adidas = os.listdir(test_adidas_dir)
temp_train_adidas = os.listdir(train_adidas_dir)
temp_val_adidas = os.listdir(val_adidas_dir)

for file in temp_test_adidas:
  new_path = shutil.move(f"{test_adidas_dir}/{file}", adidas_images)

for file in temp_train_adidas:
  new_path = shutil.move(f"{train_adidas_dir}/{file}", adidas_images)

for file in temp_val_adidas:
  new_path = shutil.move(f"{val_adidas_dir}/{file}", adidas_images)

# %% [markdown]
# **NIKE**

# %%
temp_test_nike = os.listdir(test_nike_dir)
temp_train_nike = os.listdir(train_nike_dir)
temp_val_nike = os.listdir(val_nike_dir)

for file in temp_test_nike:
  new_path = shutil.move(f"{test_nike_dir}/{file}", nike_images)

for file in temp_train_nike:
  new_path = shutil.move(f"{train_nike_dir}/{file}", nike_images)

for file in temp_val_nike:
  new_path = shutil.move(f"{val_nike_dir}/{file}", nike_images)

# %%
print("Total Image Adidas", len(os.listdir(adidas_images)))
print("Total Image Adidas", len(os.listdir(nike_images)))
# Out:
# Total Image Adidas 286
# Total Image Adidas 288

# %%
data_dir = "/content/gdrive/MyDrive/MachineLearning/shoes/"
output = "/content/gdrive/MyDrive/MachineLearning/splitt"
splitfolders.ratio(data_dir, output=output, seed=1337, ratio=(0.7, 0.3))
# Out:
# Copying files: 574 files [00:10, 52.47 files/s]

# %% [markdown]
# **GATHER**

# %%
train_dir = "/content/gdrive/MyDrive/MachineLearning/splitt/train"
val_dir = "/content/gdrive/MyDrive/MachineLearning/splitt/val"

# %%
trainX = []
trainY = []
for r, d, f in os.walk(train_dir):
    for file in f:
        if ".jpg" in file:
            imagePath = os.path.join(r, file)
            image = cv2.imread(imagePath)
            image = cv2.resize(image, (150,150))
            trainX.append(image)
            label = imagePath.split(os.path.sep)[-2]
            trainY.append(label)

trainX = np.array(trainX)
trainY = np.array(trainY)

# %%
valX = []
valY = []
for r, d, f in os.walk(val_dir):
    for file in f:
        if ".jpg" in file:
            imagePath = os.path.join(r, file)
            image = cv2.imread(imagePath)
            image = cv2.resize(image, (150,150))
            valX.append(image)
            label = imagePath.split(os.path.sep)[-2]
            valY.append(label)

valX = np.array(valX)
valY = np.array(valY)

# %%
print("Train Data=", trainX.shape)
print("Train Label=", trainY.shape)
print("Validation Data=", valX.shape)
print("Validation Label=", valY.shape)
# Out:
# Train Data= (387, 150, 150, 3)
# Train Label= (387,)
# Validation Data= (165, 150, 150, 3)
# Validation Label= (165,)

# %%
train_adidas = "/content/gdrive/MyDrive/MachineLearning/splitt/train/adidas"
val_adidas = "/content/gdrive/MyDrive/MachineLearning/splitt/val/adidas"
train_nike = "/content/gdrive/MyDrive/MachineLearning/splitt/train/nike"
val_nike = "/content/gdrive/MyDrive/MachineLearning/splitt/val/nike"

print('total adidas train data:', len(os.listdir(train_adidas)))
print('total adidas valdation data:', len(os.listdir(val_adidas)))
print('total nike train data:', len(os.listdir(train_nike)))
print('total nike valdation data:', len(os.listdir(val_nike)))
# Out:
# total adidas train data: 200
# total adidas valdation data: 86
# total nike train data: 201
# total nike valdation data: 87

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

nrows = 2
ncols = 4

pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 4
adidas_pix = [os.path.join(train_adidas, fname) 
                for fname in os.listdir(train_adidas)[pic_index-4:pic_index]]
nike_pix = [os.path.join(train_nike, fname) 
                for fname in os.listdir(train_nike)[pic_index-4:pic_index]]

for i, img_path in enumerate(adidas_pix+nike_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
lb = LabelEncoder()
trainY = lb.fit_transform(trainY)
valY = lb.fit_transform(valY)

# %%
print('Train min=%.f, max=%.f' % (trainX.min(), trainX.max()))
print('Validation min=%.f, max=%.f' % (valX.min(), valX.max()))
# Out:
# Train min=0, max=255
# Validation min=0, max=255

# %%
datagen = ImageDataGenerator(rescale=1.0/255.0)

# %%
train_iterator = datagen.flow(trainX, trainY, batch_size=64)
val_iterator = datagen.flow(valX, valY, batch_size=64)
print('Batches train=%d, validation=%d' % (len(train_iterator), len(val_iterator)))
# Out:
# Batches train=7, validation=3

# %%
batchX, batchy = train_iterator.next()
print('Batch shape=%s, min=%.3f, max=%.3f' % (batchX.shape, batchX.min(), batchX.max()))
# Out:
# Batch shape=(64, 150, 150, 3), min=0.000, max=1.000

# %% [markdown]
# ---

# %% [markdown]
# ## **MODELING**

# %%
from keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report
import os
import zipfile
import shutil
import cv2
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, Conv2D, AveragePooling2D, GlobalAveragePooling2D, MaxPool2D, Flatten
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.layers import Dropout, SpatialDropout2D, BatchNormalization

# %% [markdown]
# ### **MODELING SKENARIO 1**

# %%
# build a simple model
model = Sequential()
model.add(InputLayer(input_shape=[150, 150, 3]))
model.add(Conv2D(filters=32, kernel_size=3, strides=1, padding='same', activation='relu'))
model.add(SpatialDropout2D(rate=0.5))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=2, padding='same'))

model.add(Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='relu'))
model.add(SpatialDropout2D(rate=0.5))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=2, padding='same'))

model.add(Conv2D(filters=128, kernel_size=3, strides=1, padding='same', activation='relu'))
model.add(SpatialDropout2D(rate=0.5))
model.add(BatchNormalization())
model.add(Flatten())

# fully connected
model.add(Dense(512, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 150, 150, 32)      896
#
#  spatial_dropout2d_3 (Spatia  (None, 150, 150, 32)     0
#  lDropout2D)
#
#  batch_normalization_3 (Batc  (None, 150, 150, 32)     128
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 75, 75, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 75, 75, 64)        18496
#
#  spatial_dropout2d_4 (Spatia  (None, 75, 75, 64)       0
#  lDropout2D)
#
#  batch_normalization_4 (Batc  (None, 75, 75, 64)       256
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 38, 38, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 38, 38, 128)       73856
#
#  spatial_dropout2d_5 (Spatia  (None, 38, 38, 128)      0
#  lDropout2D)
#
#  batch_normalization_5 (Batc  (None, 38, 38, 128)      512
#  hNormalization)
#
#  flatten_1 (Flatten)         (None, 184832)            0
#
#  dense_2 (Dense)             (None, 512)               94634496
#
#  dense_3 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 94,729,153
# Trainable params: 94,728,705
# Non-trainable params: 448
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
H = model.fit(train_iterator, epochs=50, validation_data=val_iterator)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 36s 5s/step - loss: 0.0444 - accuracy: 0.9793 - val_loss: 1.7979 - val_accuracy: 0.6848
# Epoch 2/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0299 - accuracy: 0.9897 - val_loss: 1.7896 - val_accuracy: 0.6848
# Epoch 3/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0321 - accuracy: 0.9871 - val_loss: 1.7876 - val_accuracy: 0.6848
# Epoch 4/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0306 - accuracy: 0.9871 - val_loss: 1.8167 - val_accuracy: 0.6848
# Epoch 5/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0223 - accuracy: 0.9922 - val_loss: 1.8025 - val_accuracy: 0.6727
# Epoch 6/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.1717 - accuracy: 0.9509 - val_loss: 2.0161 - val_accuracy: 0.6788
# Epoch 7/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0950 - accuracy: 0.9767 - val_loss: 1.9616 - val_accuracy: 0.6727
# Epoch 8/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0778 - accuracy: 0.9793 - val_loss: 1.7431 - val_accuracy: 0.6788
# Epoch 9/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0284 - accuracy: 0.9897 - val_loss: 1.7935 - val_accuracy: 0.6848
# Epoch 10/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0282 - accuracy: 0.9871 - val_loss: 1.8087 - val_accuracy: 0.6909
# Epoch 11/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0178 - accuracy: 0.9948 - val_loss: 1.8641 - val_accuracy: 0.6909
# Epoch 12/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0445 - accuracy: 0.9871 - val_loss: 1.8942 - val_accuracy: 0.6909
# Epoch 13/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0235 - accuracy: 0.9948 - val_loss: 1.8984 - val_accuracy: 0.6848
# Epoch 14/50
# 7/7 [==============================] - 35s 5s/step - loss: 0.0303 - accuracy: 0.9871 - val_loss: 1.9340 - val_accuracy: 0.6909
# Epoch 15/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0161 - accuracy: 0.9922 - val_loss: 1.9841 - val_accuracy: 0.6848
# Epoch 16/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0122 - accuracy: 0.9974 - val_loss: 2.0462 - val_accuracy: 0.6848
# Epoch 17/50
# 7/7 [==============================] - 36s 6s/step - loss: 0.0239 - accuracy: 0.9871 - val_loss: 2.0759 - val_accuracy: 0.6909
# Epoch 18/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0246 - accuracy: 0.9948 - val_loss: 2.1340 - val_accuracy: 0.6970
# Epoch 19/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0280 - accuracy: 0.9897 - val_loss: 2.0720 - val_accuracy: 0.6788
# Epoch 20/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0168 - accuracy: 0.9948 - val_loss: 2.1283 - val_accuracy: 0.6667
# Epoch 21/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0272 - accuracy: 0.9897 - val_loss: 2.1287 - val_accuracy: 0.6909
# Epoch 22/50
# 7/7 [==============================] - 35s 5s/step - loss: 0.0128 - accuracy: 0.9974 - val_loss: 2.1528 - val_accuracy: 0.6848
# Epoch 23/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0210 - accuracy: 0.9897 - val_loss: 2.1704 - val_accuracy: 0.6909
# Epoch 24/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0103 - accuracy: 0.9948 - val_loss: 2.1821 - val_accuracy: 0.6848
# Epoch 25/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0135 - accuracy: 0.9948 - val_loss: 2.1812 - val_accuracy: 0.6909
# Epoch 26/50
# Epoch 46/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0289 - accuracy: 0.9871 - val_loss: 2.4201 - val_accuracy: 0.6848
# Epoch 47/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0149 - accuracy: 0.9974 - val_loss: 2.5183 - val_accuracy: 0.6788
# Epoch 48/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0350 - accuracy: 0.9871 - val_loss: 2.3563 - val_accuracy: 0.6909
# Epoch 49/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.0354 - accuracy: 0.9871 - val_loss: 2.3171 - val_accuracy: 0.6788
# Epoch 50/50
# 7/7 [==============================] - 39s 5s/step - loss: 0.0603 - accuracy: 0.9819 - val_loss: 2.2963 - val_accuracy: 0.6848

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 50), H.history["val_loss"], label="val_loss")
plt.title("Loss Plot")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# plotting accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), H.history["accuracy"], label="train_accuracy")
plt.plot(np.arange(0, 50), H.history["val_accuracy"], label="val_accuracy")
plt.title("Accuracy Plot")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
model.save("Model.h5")

# %% [markdown]
# ### **MODELING SKENARIO 2**

# %%
# build a simple model
model = Sequential()
model.add(InputLayer(input_shape=[150, 150, 3]))
model.add(Conv2D(filters=32, kernel_size=3, strides=1, padding='same', activation='relu'))
model.add(SpatialDropout2D(rate=0.5))
model.add(BatchNormalization())
model.add(AveragePooling2D(pool_size=2, padding='same'))

model.add(Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='relu'))
model.add(SpatialDropout2D(rate=0.5))
model.add(BatchNormalization())
model.add(AveragePooling2D(pool_size=2, padding='same'))

model.add(Conv2D(filters=128, kernel_size=3, strides=1, padding='same', activation='relu'))
model.add(SpatialDropout2D(rate=0.5))
model.add(BatchNormalization())
model.add(GlobalAveragePooling2D())
model.add(Flatten())

# fully connected
model.add(Dense(512, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.summary()

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
H = model.fit(train_iterator, epochs=26, validation_data=val_iterator)

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 26), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 26), H.history["val_loss"], label="val_loss")
plt.title("Loss Plot")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 26), H.history["accuracy"], label="train_accuracy")
plt.plot(np.arange(0, 26), H.history["val_accuracy"], label="val_accuracy")
plt.title("Accuracy Plot")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
model.save("Model2.h5")

# %% [markdown]
# ## **AUGMENTASI DATA**

# %%
train_generator = ImageDataGenerator(rescale = 1/255)
train_data = train_generator.flow_from_directory('/content/gdrive/MyDrive/MachineLearning/splitt/train',
                                                 target_size = (150, 150),
                                                 batch_size = 64,
                                                 shuffle = True,
                                                 class_mode = 'binary',
                                                 color_mode = 'rgb')
# Out:
# Found 401 images belonging to 2 classes.

# %%
for _ in range(5):
      img, label = train_data.next()
      plt.imshow(img[0])
      plt.show
# Out:
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "

# %%
val_generator = ImageDataGenerator(rescale = 1/255)

val_data = val_generator.flow_from_directory('/content/gdrive/MyDrive/MachineLearning/splitt/val',
                                             target_size = (150, 150),
                                             batch_size = 64,
                                             shuffle = True,
                                             class_mode = 'binary',
                                             color_mode = 'rgb')
# Out:
# Found 173 images belonging to 2 classes.

# %%
for _ in range(5):
      img, label = val_data.next()
      plt.imshow(img[0])
      plt.show

# %% [markdown]
# ### **MODELLING SKENARIO 3**

# %%
#konstruksi moodel
model = Sequential()
model.add(InputLayer(input_shape=[150, 150, 3]))
model.add(Conv2D(filters=32, kernel_size=3, strides=1, padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=5, padding='same'))

model.add(Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=5, padding='same'))
model.add(BatchNormalization())

model.add(Conv2D(filters=128, kernel_size=3, strides=1, padding='same', activation='relu'))
model.add(SpatialDropout2D(0.5))
model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 150, 150, 32)      896
#
#  max_pooling2d_16 (MaxPoolin  (None, 30, 30, 32)       0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 30, 30, 64)        18496
#
#  max_pooling2d_17 (MaxPoolin  (None, 6, 6, 64)         0
#  g2D)
#
#  batch_normalization_2 (Batc  (None, 6, 6, 64)         256
#  hNormalization)
#
#  conv2d_20 (Conv2D)          (None, 6, 6, 128)         73856
#
#  spatial_dropout2d (SpatialD  (None, 6, 6, 128)        0
#  ropout2D)
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 512)               2359808
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 2,453,825
# Trainable params: 2,453,697
# Non-trainable params: 128
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
H = model.fit(train_data, epochs=100, validation_data=val_data)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.8230 - accuracy: 0.6259 - val_loss: 0.6981 - val_accuracy: 0.5029
# Epoch 2/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.5711 - accuracy: 0.7257 - val_loss: 0.6827 - val_accuracy: 0.6994
# Epoch 3/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.4573 - accuracy: 0.7855 - val_loss: 0.6742 - val_accuracy: 0.6763
# Epoch 4/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.3594 - accuracy: 0.8379 - val_loss: 0.6811 - val_accuracy: 0.5145
# Epoch 5/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.3404 - accuracy: 0.8429 - val_loss: 0.6456 - val_accuracy: 0.6821
# Epoch 6/100
step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.7372 - val_accuracy: 0.7399
# Epoch 44/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0113 - accuracy: 0.9975 - val_loss: 0.6950 - val_accuracy: 0.7688
# Epoch 45/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0247 - accuracy: 0.9900 - val_loss: 0.7079 - val_accuracy: 0.7803
# Epoch 46/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0153 - accuracy: 0.9925 - val_loss: 0.7643 - val_accuracy: 0.7746
# Epoch 47/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0208 - accuracy: 0.9900 - val_loss: 1.8924 - val_accuracy: 0.6301
# Epoch 48/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0233 - accuracy: 0.9875 - val_loss: 0.7679 - val_accuracy: 0.7341
# Epoch 49/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.0235 - accuracy: 0.9950 - val_loss: 0.7939 - val_accuracy: 0.7457
# Epoch 50/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0116 - accuracy: 0.9975 - val_loss: 0.9826 - val_accuracy: 0.7341
# Epoch 51/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0087 - accuracy: 0.9975 - val_loss: 0.8651 - val_accuracy: 0.7341
# Epoch 52/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0049 - accuracy: 0.9975 - val_loss: 0.8382 - val_accuracy: 0.7457
# Epoch 53/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0128 - accuracy: 0.9950 - val_loss: 0.8006 - val_accuracy: 0.7514
# Epoch 54/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0206 - accuracy: 0.9925 - val_loss: 1.4601 - val_accuracy: 0.6821
# Epoch 55/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0543 - accuracy: 0.9850 - val_loss: 0.8666 - val_accuracy: 0.7457
# Epoch 56/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.0863 - accuracy: 0.9651 - val_loss: 1.0288 - val_accuracy: 0.7110
# Epoch 57/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.0783 - accuracy: 0.9726 - val_loss: 0.8483 - val_accuracy: 0.7225
# Epoch 58/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.0817 - accuracy: 0.9800 - val_loss: 0.7139 - val_accuracy: 0.7283
# Epoch 59/100
# 7/7 [==============================] - 11s 1s/step - loss: 0.0732 - accuracy: 0.9825 - val_loss: 1.0447 - val_accuracy: 0.6705
# Epoch 60/100
# 7/7 [==============================] - 11s 2s/step - loss: 0.0342 - accuracy: 0.9875 - val_loss: 0.8071 - val_accuracy: 0.7457
# Epoch 61/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0431 - accuracy: 0.9925 - val_loss: 0.8269 - val_accuracy: 0.7052
# Epoch 62/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0303 - accuracy: 0.9925 - val_loss: 0.8326 - val_accuracy: 0.7688
# Epoch 63/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.0241 - accuracy: 0.9875 - val_loss: 0.8702 - val_accuracy: 0.7688
# Epoch 64/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0179 - accuracy: 0.9950 - val_loss: 1.0332 - val_accuracy: 0.7341
# Epoch 65/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.0191 - accuracy: 0.9900 - val_loss: 0.9664 - val_accuracy: 0.7861
# Epoch 66/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0090 - accuracy: 0.9950 - val_loss: 1.0605 - val_accuracy: 0.7861
# Epoch 67/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0118 - accuracy: 0.9950 - val_loss: 1.0857 - val_accuracy: 0.7919
# Epoch 68/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0102 - accuracy: 0.9925 - val_loss: 1.0393 - val_accuracy: 0.7919
# Epoch 69/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0269 - accuracy: 0.9925 - val_loss: 1.0722 - val_accuracy: 0.7919
# Epoch 70/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0124 - accuracy: 0.9950 - val_loss: 1.0848 - val_accuracy: 0.8035
# Epoch 71/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0144 - accuracy: 0.9925 - val_loss: 1.0801 - val_accuracy: 0.8150
# Epoch 72/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0245 - accuracy: 0.9900 - val_loss: 1.0411 - val_accuracy: 0.7803
# Epoch 73/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.0093 - accuracy: 0.9925 - val_loss: 1.1144 - val_accuracy: 0.8035
# Epoch 74/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0108 - accuracy: 0.9975 - val_loss: 1.1305 - val_accuracy: 0.7803
# Epoch 75/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0081 - accuracy: 0.9975 - val_loss: 1.2013 - val_accuracy: 0.7919
# Epoch 76/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.0111 - accuracy: 0.9975 - val_loss: 1.2484 - val_accuracy: 0.7803
# Epoch 77/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.0101 - accuracy: 0.9950 - val_loss: 1.2465 - val_accuracy: 0.7919
# Epoch 78/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0098 - accuracy: 0.9975 - val_loss: 1.2122 - val_accuracy: 0.8035
# Epoch 79/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0095 - accuracy: 0.9950 - val_loss: 1.2469 - val_accuracy: 0.7919
# Epoch 80/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0086 - accuracy: 0.9950 - val_loss: 1.2956 - val_accuracy: 0.7919
# Epoch 81/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0054 - accuracy: 0.9975 - val_loss: 1.3188 - val_accuracy: 0.8035
# Epoch 82/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0077 - accuracy: 0.9950 - val_loss: 1.1628 - val_accuracy: 0.7803
# Epoch 83/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0560 - accuracy: 0.9850 - val_loss: 1.2158 - val_accuracy: 0.7803
# Epoch 84/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0208 - accuracy: 0.9925 - val_loss: 1.7955 - val_accuracy: 0.7283
# Epoch 85/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0123 - accuracy: 0.9950 - val_loss: 1.1288 - val_accuracy: 0.7803
# Epoch 86/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0117 - accuracy: 0.9950 - val_loss: 1.0997 - val_accuracy: 0.7630
# Epoch 87/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0199 - accuracy: 0.9925 - val_loss: 1.1594 - val_accuracy: 0.7399
# Epoch 88/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0191 - accuracy: 0.9900 - val_loss: 1.3590 - val_accuracy: 0.6994
# Epoch 89/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0141 - accuracy: 0.9950 - val_loss: 1.8268 - val_accuracy: 0.6936
# Epoch 90/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.0092 - accuracy: 0.9975 - val_loss: 1.3534 - val_accuracy: 0.7630
# Epoch 91/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0291 - accuracy: 0.9900 - val_loss: 1.4301 - val_accuracy: 0.7514
# Epoch 92/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.0107 - accuracy: 0.9950 - val_loss: 1.4800 - val_accuracy: 0.7572
# Epoch 93/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.0165 - accuracy: 0.9925 - val_loss: 1.4128 - val_accuracy: 0.7630
# Epoch 94/100
# 7/7 [==============================] - 10s 1s/step - loss: 0.0340 - accuracy: 0.9925 - val_loss: 1.5778 - val_accuracy: 0.7977
# Epoch 95/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0269 - accuracy: 0.9875 - val_loss: 1.4265 - val_accuracy: 0.7861
# Epoch 96/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0232 - accuracy: 0.9925 - val_loss: 1.4121 - val_accuracy: 0.7630
# Epoch 97/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0185 - accuracy: 0.9925 - val_loss: 1.5066 - val_accuracy: 0.7861
# Epoch 98/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0398 - accuracy: 0.9900 - val_loss: 1.4332 - val_accuracy: 0.7514
# Epoch 99/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0122 - accuracy: 0.9975 - val_loss: 1.9185 - val_accuracy: 0.7514
# Epoch 100/100
# 7/7 [==============================] - 9s 1s/step - loss: 0.0189 - accuracy: 0.9925 - val_loss: 1.7682 - val_accuracy: 0.7514

# %%
plt.style.use("ggplot")
plt.figure()
#plt.axis(0,15,0,8)
plt.plot(np.arange(0, 100), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 100), H.history["val_loss"], label="val_loss")
plt.title("Loss Plot")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
model.save('/content/gdrive/MyDrive/MachineLearning/Model4.h5')

# %%
plt.style.use("ggplot")
plt.figure()
#plt.axis(0,15,0,8)
plt.plot(np.arange(0, 100), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 100), H.history["val_loss"], label="val_loss")
plt.title("Loss Plot")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
model.save('/content/gdrive/MyDrive/MachineLearning/Model3.h5')
